# %%
"""
This file can be used to try a live prediction. 
"""

import keras
import librosa
import os 
from tqdm import tqdm

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec


from config import EXAMPLES_PATH
from config import MODEL_DIR_PATH

# %%
class LivePredictions:
    """
    Main class of the application.
    """

    def __init__(self, file):
        """
        Init method is used to initialize the main parameters.
        """
        self.file = file
        self.path = MODEL_DIR_PATH + '/Emotion_Voice_Detection_Model.h5'
        self.loaded_model = keras.models.load_model(self.path)

    def make_predictions(self, sample_len=2, overlap=1):
        print(f'Start Predicting {self.file}')

        # Load data with librosa
        data, sampling_rate = librosa.load(self.file, sr=None)

        # Collecting data for plots
        energy_map = {'neutral': 3, 'calm': 1, 'happy': 7, 'sad': 2, 'angry': 9, 'fearful': 8, 'disgust': 5, 'surprised': 8}
        time_stamps = []
        energy_scores = []

        # Parameters for 3s window with 1s overlap
        window_length = int(sample_len * sampling_rate)  # 3 seconds window
        overlap = int(overlap * sampling_rate)        # 1 second overlap
        step_size = window_length - overlap

        start = 0
        while start < len(data):
            end = min(start + window_length, len(data))
            chunk = data[start:end]
            mfccs = np.mean(librosa.feature.mfcc(y=chunk, sr=sampling_rate, n_mfcc=40).T, axis=0)
            x = np.expand_dims(mfccs, axis=0)
            predictions = self.loaded_model.predict(x, verbose=0)
            predicted_class = np.argmax(predictions, axis=1)
            emotion = self.convert_class_to_emotion(predicted_class[0])

            # Collecting data for energy plot
            time_stamps.append(start / sampling_rate)
            energy_scores.append(energy_map[emotion])

            print("Prediction for chunk starting at {:.2f} seconds is: {}".format(start / sampling_rate, emotion))

            if end == len(data):
                break

            start += step_size

        # Plotting
        self.plot_data(data, sampling_rate, time_stamps, energy_scores)

    def plot_data(self, audio_data, sampling_rate, time_stamps, energy_scores):
        fig = plt.figure(figsize=(10, 5))

        # Create a GridSpec with 3 rows and 1 column with custom height ratios
        gs = gridspec.GridSpec(3, 1, height_ratios=[3, 1, 1])

        # Mel Spectrogram
        ax0 = plt.subplot(gs[0])
        S = librosa.feature.melspectrogram(y=audio_data, sr=sampling_rate)
        img = librosa.display.specshow(librosa.power_to_db(S, ref=np.max), sr=sampling_rate, y_axis='mel', ax=ax0)
        ax0.set_xticklabels([])

        # 1D Sound Wave
        ax1 = plt.subplot(gs[1])
        ax1.plot(np.linspace(0, len(audio_data) / sampling_rate, len(audio_data)), audio_data)
        ax1.set_ylabel('Amplitude')
        ax1.set_xticklabels([])

        # Emotion Energy Over Time
        ax2 = plt.subplot(gs[2])
        ax2.plot(time_stamps, energy_scores, marker='o')
        ax2.set_xlabel('Time (s)')
        ax2.set_ylabel('Energy Level')

        # Adjust layout and display the combined plot            
        plt.subplots_adjust(wspace=0, hspace=0)
        # plt.show()


        save_name = os.path.basename(live_prediction.file).split('.')[0] + '.jpg'
        plt.savefig(f'figs/{save_name}')



    @staticmethod
    def convert_class_to_emotion(pred):
        """
        Method to convert the predictions (int) into human readable strings.
        """
        
        label_conversion = {'0': 'neutral',
                            '1': 'calm',
                            '2': 'happy',
                            '3': 'sad',
                            '4': 'angry',
                            '5': 'fearful',
                            '6': 'disgust',
                            '7': 'surprised'}

        for key, value in label_conversion.items():
            if int(key) == pred:
                label = value
        return label

# %%
live_prediction = LivePredictions(file=EXAMPLES_PATH + '/03-01-01-01-01-02-05.wav')
live_prediction.make_predictions()

live_prediction = LivePredictions(file=EXAMPLES_PATH + '/10-16-07-29-82-30-63.wav')
live_prediction.make_predictions()

live_prediction = LivePredictions(file=EXAMPLES_PATH + '/trimmed.mp3')
live_prediction.make_predictions()
# Out:
# Start Predicting /root/ED/emotion-classification-from-audio-files/examples/03-01-01-01-01-02-05.wav
# Prediction for chunk starting at 0.00 seconds is: sad
# Prediction for chunk starting at 0.50 seconds is: sad
# Prediction for chunk starting at 1.00 seconds is: sad
# Prediction for chunk starting at 1.50 seconds is: sad
# Prediction for chunk starting at 2.00 seconds is: neutral
# Start Predicting /root/ED/emotion-classification-from-audio-files/examples/10-16-07-29-82-30-63.wav
# Prediction for chunk starting at 0.00 seconds is: disgust
# Prediction for chunk starting at 0.50 seconds is: sad
# Start Predicting /root/ED/emotion-classification-from-audio-files/examples/trimmed.mp3
# Prediction for chunk starting at 0.00 seconds is: disgust
# Prediction for chunk starting at 0.50 seconds is: disgust
# Prediction for chunk starting at 1.00 seconds is: disgust
# Prediction for chunk starting at 1.50 seconds is: disgust
# Prediction for chunk starting at 2.00 seconds is: disgust
# Prediction for chunk starting at 2.50 seconds is: disgust
# Prediction for chunk starting at 3.00 seconds is: disgust
# Prediction for chunk starting at 3.50 seconds is: disgust
# Prediction for chunk starting at 4.00 seconds is: disgust
# Prediction for chunk starting at 4.50 seconds is: disgust
# Prediction for chunk starting at 5.00 seconds is: disgust
# Prediction for chunk starting at 5.50 seconds is: disgust
# Prediction for chunk starting at 6.00 seconds is: disgust
# Prediction for chunk starting at 6.50 seconds is: disgust
# Prediction for chunk starting at 7.00 seconds is: disgust
# Prediction for chunk starting at 7.50 seconds is: disgust
# Prediction for chunk starting at 8.00 seconds is: disgust
# Prediction for chunk starting at 8.50 seconds is: disgust
# Prediction for chunk starting at 9.00 seconds is: disgust
# Prediction for chunk starting at 9.50 seconds is: disgust
# Prediction for chunk starting at 10.00 seconds is: disgust
# Prediction for chunk starting at 10.50 seconds is: disgust
# Prediction for chunk starting at 11.00 seconds is: disgust
# Prediction for chunk starting at 11.50 seconds is: disgust
# Prediction for chunk starting at 12.00 seconds is: disgust
# Prediction for chunk starting at 12.50 seconds is: disgust
# Prediction for chunk starting at 13.00 seconds is: disgust
# Prediction for chunk starting at 13.50 seconds is: sad
# Prediction for chunk starting at 14.00 seconds is: sad
# Prediction for chunk starting at 14.50 seconds is: sad
# Prediction for chunk starting at 15.00 seconds is: disgust
# Prediction for chunk starting at 15.50 seconds is: disgust
# Prediction for chunk starting at 16.00 seconds is: disgust
# Prediction for chunk starting at 16.50 seconds is: disgust
# Prediction for chunk starting at 17.00 seconds is: disgust
# Prediction for chunk starting at 17.50 seconds is: sad
# Prediction for chunk starting at 18.00 seconds is: sad
# Prediction for chunk starting at 18.50 seconds is: disgust
# Prediction for chunk starting at 19.00 seconds is: disgust
# Prediction for chunk starting at 19.50 seconds is: disgust
# Prediction for chunk starting at 20.00 seconds is: disgust
# Prediction for chunk starting at 20.50 seconds is: disgust
# Prediction for chunk starting at 21.00 seconds is: disgust
# Prediction for chunk starting at 21.50 seconds is: disgust
# Prediction for chunk starting at 22.00 seconds is: disgust
# Prediction for chunk starting at 22.50 seconds is: disgust
# Prediction for chunk starting at 23.00 seconds is: disgust
# Prediction for chunk starting at 23.50 seconds is: disgust
# Prediction for chunk starting at 24.00 seconds is: disgust
# Prediction for chunk starting at 24.50 seconds is: disgust
# Prediction for chunk starting at 25.00 seconds is: disgust
# Prediction for chunk starting at 25.50 seconds is: disgust
# Prediction for chunk starting at 26.00 seconds is: disgust
# Prediction for chunk starting at 26.50 seconds is: disgust
# Prediction for chunk starting at 27.00 seconds is: disgust
# Prediction for chunk starting at 27.50 seconds is: disgust
# Prediction for chunk starting at 28.00 seconds is: disgust
# Prediction for chunk starting at 28.50 seconds is: disgust
# Prediction for chunk starting at 29.00 seconds is: disgust
# Prediction for chunk starting at 29.50 seconds is: disgust
# Prediction for chunk starting at 30.00 seconds is: disgust
# Prediction for chunk starting at 30.50 seconds is: disgust
# Prediction for chunk starting at 31.00 seconds is: disgust
# Prediction for chunk starting at 31.50 seconds is: disgust
# Prediction for chunk starting at 32.00 seconds is: disgust
# Prediction for chunk starting at 32.50 seconds is: disgust
# Prediction for chunk starting at 33.00 seconds is: sad
# Prediction for chunk starting at 33.50 seconds is: disgust
# Prediction for chunk starting at 34.00 seconds is: disgust
# Prediction for chunk starting at 34.50 seconds is: disgust
# Prediction for chunk starting at 35.00 seconds is: disgust
# Prediction for chunk starting at 35.50 seconds is: disgust
# Prediction for chunk starting at 36.00 seconds is: disgust
# Prediction for chunk starting at 36.50 seconds is: disgust
# Prediction for chunk starting at 37.00 seconds is: disgust
# Prediction for chunk starting at 37.50 seconds is: disgust
# Prediction for chunk starting at 38.00 seconds is: disgust
# Prediction for chunk starting at 38.50 seconds is: disgust
# Prediction for chunk starting at 39.00 seconds is: disgust
# Prediction for chunk starting at 39.50 seconds is: disgust
# Prediction for chunk starting at 40.00 seconds is: disgust
# Prediction for chunk starting at 40.50 seconds is: disgust
# Prediction for chunk starting at 41.00 seconds is: disgust
# Prediction for chunk starting at 41.50 seconds is: disgust
# Prediction for chunk starting at 42.00 seconds is: sad
# Prediction for chunk starting at 42.50 seconds is: disgust
# Prediction for chunk starting at 43.00 seconds is: disgust
# Prediction for chunk starting at 43.50 seconds is: disgust
# Prediction for chunk starting at 44.00 seconds is: disgust
# Prediction for chunk starting at 44.50 seconds is: disgust
# Prediction for chunk starting at 45.00 seconds is: disgust
# Prediction for chunk starting at 45.50 seconds is: disgust
# Prediction for chunk starting at 46.00 seconds is: disgust
# Prediction for chunk starting at 46.50 seconds is: disgust
# Prediction for chunk starting at 47.00 seconds is: disgust
# Prediction for chunk starting at 47.50 seconds is: disgust
# Prediction for chunk starting at 48.00 seconds is: disgust
# Prediction for chunk starting at 48.50 seconds is: disgust
# Prediction for chunk starting at 49.00 seconds is: disgust
# Prediction for chunk starting at 49.50 seconds is: disgust
# Prediction for chunk starting at 50.00 seconds is: disgust
# Prediction for chunk starting at 50.50 seconds is: disgust
# Prediction for chunk starting at 51.00 seconds is: disgust
# Prediction for chunk starting at 51.50 seconds is: disgust
# Prediction for chunk starting at 52.00 seconds is: disgust
# Prediction for chunk starting at 52.50 seconds is: disgust
# Prediction for chunk starting at 53.00 seconds is: disgust
# Prediction for chunk starting at 53.50 seconds is: disgust
# Prediction for chunk starting at 54.00 seconds is: disgust
# Prediction for chunk starting at 54.50 seconds is: disgust
# Prediction for chunk starting at 55.00 seconds is: sad
# Prediction for chunk starting at 55.50 seconds is: sad
# Prediction for chunk starting at 56.00 seconds is: disgust
# Prediction for chunk starting at 56.50 seconds is: disgust
# Prediction for chunk starting at 57.00 seconds is: disgust
# Prediction for chunk starting at 57.50 seconds is: disgust
# Prediction for chunk starting at 58.00 seconds is: disgust
# Prediction for chunk starting at 58.50 seconds is: disgust
# Prediction for chunk starting at 59.00 seconds is: disgust
